# %%
import re
city = "Zürich"
city_file = re.sub(r'[^\w\-.]', '_', city).strip().replace(' ', '_').replace("ä", "ae").replace("ö", "oe").replace("ü", "ue").lower()
city_file
# Out:
# 'zuerich'

# %%
city_file
# Out:
# 'Zürich'
